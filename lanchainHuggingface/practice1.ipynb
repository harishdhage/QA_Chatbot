# %% [markdown]
# #### Lancgchain + Hugginnface

# %%
import os
from dotenv import load_dotenv
load_dotenv()

# %% [markdown]
# #### Huggingface endpoint
# this will support to use the model from huggingface

# %%
from langchain_huggingface import HuggingFaceEndpoint
llm = HuggingFaceEndpoint(repo_id="microsoft/FastContext-1.0-4B-SFT",
                          #provider="",
                          max_new_tokens=300,
                          huggingfacehub_api_token=os.environ["HF_TOKEN"],
                          temperature=0.7
                          )
llm
